# %% [markdown]
# Premiers exercices

# %%
print("Analyse Bourse")
# Out:
# Analyse Bourse

# %% [markdown]
# # Let's go learning PYTHON

# %%
# Ceci est un commentaire dans la cellule du code 
# Pyhton est une programmation orienté OBJET. On définit les variables 
name = "AJLA"
name
# Out:
# 'AJLA'

# %%
name = "Louanne"
name 
# La dernière def de la variable l'emporte
# Out:
# 'Louanne'

# %%
# Pour les chiffres on a 
age = 26 # INTEGRER donc les nombres entier 
print(age)
# Out:
# 26

# %%
pi = 3,14
pi
# Out:
# (3, 14)

# %%
# un dictionnaire c'est CLÉ valeur 

prices = {
    "APPL":248.04,
    "GOOGLE":328.33,
    "TSLA":437.43
}

# %%
prices
# Out:
# {'APPL': 248.04, 'GOOGLE': 328.33, 'TSLA': 437.43}

# %% [markdown]
# # Comment avoir les données boursières
# # En effet, on ne va pas recopier à la main des dictionnaires

# %% [markdown]
# # Donc on utilise les PACKAGES

# %%
! pip install yfinance 
# YAHOO FINANCE
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
! pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import yfinance as yf

# %% [markdown]
# # La structure d'un projet python :
#  Une cellule où l'on importe TOUS LES PACKAGES
#  Comme ça on a une overview des DEPENDANCES

# %%
import yfinance as yf 
import pandas as pd 
import numpy as np 
import matplotlib

# %%
ticker = "AAPL"

# %%
# Pour prendre les données de PACKAGE Yfinance on utilise 
# une FONCTION qui est def dans ce package pour EXTRAIRE la donnée 
data = yf.download(ticker , start="2020-01-01", auto_adjust=False)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            AAPL        AAPL        AAPL        AAPL        AAPL
# Date
# 2020-01-02   72.468254   75.087502   75.150002   73.797501   74.059998
# 2020-01-03   71.763710   74.357498   75.144997   74.125000   74.287498
# 2020-01-06   72.335579   74.949997   74.989998   73.187500   73.447502
# 2020-01-07   71.995369   74.597504   75.224998   74.370003   74.959999
# 2020-01-08   73.153488   75.797501   76.110001   74.290001   74.290001
# ...                ...         ...         ...         ...         ...
# 2026-01-26  255.410004  255.410004  256.559998  249.800003  251.479996
# 2026-01-27  258.269989  258.269989  261.950012  258.209991  259.170013
# 2026-01-28  256.440002  256.440002  258.859985  254.509995  257.649994
# 2026-01-29  258.279999  258.279999  259.649994  254.410004  258.000000
# 2026-01-30  259.480011  259.480011  261.899994  252.179993  255.169998
#
# Price          Volume
# ...

# %%
data.head() # fct pour voir les 5 premières
data.tail() # les 5 dernières
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            AAPL        AAPL        AAPL        AAPL        AAPL
# Date
# 2026-01-26  255.410004  255.410004  256.559998  249.800003  251.479996
# 2026-01-27  258.269989  258.269989  261.950012  258.209991  259.170013
# 2026-01-28  256.440002  256.440002  258.859985  254.509995  257.649994
# 2026-01-29  258.279999  258.279999  259.649994  254.410004  258.000000
# 2026-01-30  259.480011  259.480011  261.899994  252.179993  255.169998
#
# Price         Volume
# Ticker          AAPL
# Date
# 2026-01-26  55969200
# 2026-01-27  49648300
# 2026-01-28  41288000
# 2026-01-29  67253000
# 2026-01-30  92352600

# %% [markdown]
# # Packages utilisés :
# Core analysis et financial specific
#
# Advanced Analytics :
# - scikit-learn
# - tensorflow
# - prophet
# - arch

# %%
# 2. Calculer les rendements journaliers (Daily Returns)
# On utilise le "Adj Close" (Prix ajusté aux dividendes/splits)
data ['Return'] = data ['Adj Close'].pct_change()

# 3. Calculer la volatilité et le rendement moyen (Annualisés)
# Il y a environ 252 jours de trading dans une année
mean_return_daily = data ['Return'].mean()
volatility_daily = data ['Return'].std()
annualized_return = mean_return_daily * 252
annualized_volatility = volatility_daily * np.sqrt(252)

# %%
# 4. Calcul du Ratio de Sharpe (supposons taux sans risque = 0)
sharpe_ratio = annualized_return / annualized_volatility 
print(f"--- Analyse pour {ticker} ---")
print(f"Rendement annuel moyen: {annualized_return:.2%}")
print(f"Volatilité annuelle: {annualized_volatility:.2%}")
print(f"Ratio de Sharpe: {sharpe_ratio:.2f}")
# Out:
# --- Analyse pour AAPL ---
# Rendement annuel moyen: 26.06%
# Volatilité annuelle: 31.69%
# Ratio de Sharpe: 0.82

# %%
# Plot it
from matplotlib import pyplot as plt


plt.figure(figsize=(10,6))
plt.plot(data['Adj Close'], label='AAPL Closing Price')
plt.title('Apple Stock Price Over Time')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')
